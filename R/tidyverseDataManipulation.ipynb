# %% [markdown]
# # Introduction to Tidyverse - Data Manipulation

# %% [markdown]
# ## Transforming Data: dplyr Basics

# %% [markdown]
# * Load
# the tidyverse by running:

# %%
library(tidyverse, warn.conflicts = F)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.1       v purrr   0.3.2
# v tibble  2.1.1       v dplyr   0.8.0.1
# v tidyr   0.8.3       v stringr 1.4.0
# v readr   1.3.1       v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %% [markdown]
# * "warn.conflicts = FALSE" will suppress the soft warnings.

# %% [markdown]
# ### The penguins Data Frame

# %% [markdown]
# In addition to tidyverse, we will use the Palmer penguins dataset containing body measurements for
# penguins on three islands in the Palmer Archipelago

# %% [markdown]
# ### Loading the dataset

# %%
install.packages("palmerpenguins")
library(palmerpenguins,warn.conflicts = FALSE)
data("penguins")
# Out:
# Warning message:
# "unable to access index for repository https://cran.r-project.org/bin/windows/contrib/3.6:
# installing the source package 'palmerpenguins'bin/windows/contrib/3.6/PACKAGES'"

# %% [markdown]
# ### Viewing the DataFrame

# %%
head(penguins, 10)
# Out:
#    species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1  Adelie  Torgersen 39.1           18.7          181               3750
# 2  Adelie  Torgersen 39.5           17.4          186               3800
# 3  Adelie  Torgersen 40.3           18.0          195               3250
# 4  Adelie  Torgersen   NA             NA           NA                 NA
# 5  Adelie  Torgersen 36.7           19.3          193               3450
# 6  Adelie  Torgersen 39.3           20.6          190               3650
# 7  Adelie  Torgersen 38.9           17.8          181               3625
# 8  Adelie  Torgersen 39.2           19.6          195               4675
# 9  Adelie  Torgersen 34.1           18.1          193               3475
# 10 Adelie  Torgersen 42.0           20.2          190               4250
#    sex    year
# 1  male   2007
# 2  female 2007
# 3  female 2007
# 4  NA     2007
# 5  female 2007
# 6  male   2007
# 7  female 2007
# 8  male   2007
# ...

# %% [markdown]
# * Using glimpse() to see all the variables and first few observations.

# %%
glimpse(penguins)
# Out:
# Observations: 344
# Variables: 8
# $ species           <fct> Adelie, Adelie, Adelie, Adelie, Adelie, Adelie, A...
# $ island            <fct> Torgersen, Torgersen, Torgersen, Torgersen, Torge...
# $ bill_length_mm    <dbl> 39.1, 39.5, 40.3, NA, 36.7, 39.3, 38.9, 39.2, 34....
# $ bill_depth_mm     <dbl> 18.7, 17.4, 18.0, NA, 19.3, 20.6, 17.8, 19.6, 18....
# $ flipper_length_mm <int> 181, 186, 195, NA, 193, 190, 181, 195, 193, 190, ...
# $ body_mass_g       <int> 3750, 3800, 3250, NA, 3450, 3650, 3625, 4675, 347...
# $ sex               <fct> male, female, female, NA, female, male, female, m...
# $ year              <int> 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2...

# %% [markdown]
# ## Rows

# %% [markdown]
# #### filter()

# %%
penguins  %>%  filter(bill_depth_mm > 17 ) %>% head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen 36.7           19.3          193               3450
# 5 Adelie  Torgersen 39.3           20.6          190               3650
# 6 Adelie  Torgersen 38.9           17.8          181               3625
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 female 2007
# 5 male   2007
# 6 female 2007

# %%
penguins %>% filter(bill_depth_mm > 20) %>% head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.3           20.6          190               3650
# 2 Adelie  Torgersen 42.0           20.2          190               4250
# 3 Adelie  Torgersen 38.6           21.2          191               3800
# 4 Adelie  Torgersen 34.6           21.1          198               4400
# 5 Adelie  Torgersen 42.5           20.7          197               4500
# 6 Adelie  Torgersen 46.0           21.5          194               4200
#   sex  year
# 1 male 2007
# 2 NA   2007
# 3 male 2007
# 4 male 2007
# 5 male 2007
# 6 male 2007

# %%
penguins  %>% filter(year == 2007) %>% head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %%
penguins %>% filter(sex == 'male') %>% head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.3           20.6          190               3650
# 3 Adelie  Torgersen 39.2           19.6          195               4675
# 4 Adelie  Torgersen 38.6           21.2          191               3800
# 5 Adelie  Torgersen 34.6           21.1          198               4400
# 6 Adelie  Torgersen 42.5           20.7          197               4500
#   sex  year
# 1 male 2007
# 2 male 2007
# 3 male 2007
# 4 male 2007
# 5 male 2007
# 6 male 2007

# %%
penguins %>% filter(sex == 'female') %>% head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.5           17.4          186               3800
# 2 Adelie  Torgersen 40.3           18.0          195               3250
# 3 Adelie  Torgersen 36.7           19.3          193               3450
# 4 Adelie  Torgersen 38.9           17.8          181               3625
# 5 Adelie  Torgersen 41.1           17.6          182               3200
# 6 Adelie  Torgersen 36.6           17.8          185               3700
#   sex    year
# 1 female 2007
# 2 female 2007
# 3 female 2007
# 4 female 2007
# 5 female 2007
# 6 female 2007

# %%
penguins  %>% filter(island == "Dream") %>% head()
# Out:
#   species island bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Dream  39.5           16.7          178               3250
# 2 Adelie  Dream  37.2           18.1          178               3900
# 3 Adelie  Dream  39.5           17.8          188               3300
# 4 Adelie  Dream  40.9           18.9          184               3900
# 5 Adelie  Dream  36.4           17.0          195               3325
# 6 Adelie  Dream  39.2           21.1          196               4150
#   sex    year
# 1 female 2007
# 2 male   2007
# 3 female 2007
# 4 male   2007
# 5 female 2007
# 6 male   2007

# %%
penguins %>% filter(species == 'Adelie') %>% head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %% [markdown]
# * Multiple chain conditions

# %%
penguins  %>% filter(bill_length_mm > 35 & island == "Torgersen") %>% head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen 36.7           19.3          193               3450
# 5 Adelie  Torgersen 39.3           20.6          190               3650
# 6 Adelie  Torgersen 38.9           17.8          181               3625
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 female 2007
# 5 male   2007
# 6 female 2007

# %%
penguins %>% filter(species == 'Adelie' & island == 'Torgersen') %>% head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %% [markdown]
# * Storing the filtered dataframes in different variables.

# %%
female_penguins  <- penguins  %>% filter(sex == "female")
male_penguins  <- penguins  %>% filter(sex != "female")

# %%
female_penguins
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Torgersen 39.5           17.4          186
# 2   Adelie    Torgersen 40.3           18.0          195
# 3   Adelie    Torgersen 36.7           19.3          193
# 4   Adelie    Torgersen 38.9           17.8          181
# 5   Adelie    Torgersen 41.1           17.6          182
# 6   Adelie    Torgersen 36.6           17.8          185
# 7   Adelie    Torgersen 38.7           19.0          195
# 8   Adelie    Torgersen 34.4           18.4          184
# 9   Adelie    Biscoe    37.8           18.3          174
# 10  Adelie    Biscoe    35.9           19.2          189
# 11  Adelie    Biscoe    35.3           18.9          187
# 12  Adelie    Biscoe    40.5           17.9          187
# 13  Adelie    Biscoe    37.9           18.6          172
# 14  Adelie    Dream     39.5           16.7          178
# 15  Adelie    Dream     39.5           17.8          188
# ...

# %%
male_penguins
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Torgersen 39.1           18.7          181
# 2   Adelie    Torgersen 39.3           20.6          190
# 3   Adelie    Torgersen 39.2           19.6          195
# 4   Adelie    Torgersen 38.6           21.2          191
# 5   Adelie    Torgersen 34.6           21.1          198
# 6   Adelie    Torgersen 42.5           20.7          197
# 7   Adelie    Torgersen 46.0           21.5          194
# 8   Adelie    Biscoe    37.7           18.7          180
# 9   Adelie    Biscoe    38.2           18.1          185
# 10  Adelie    Biscoe    38.8           17.2          180
# 11  Adelie    Biscoe    40.6           18.6          183
# 12  Adelie    Biscoe    40.5           18.9          180
# 13  Adelie    Dream     37.2           18.1          178
# 14  Adelie    Dream     40.9           18.9          184
# 15  Adelie    Dream     39.2           21.1          196
# ...

# %%
filter(penguins, sex == 'male') %>% head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.3           20.6          190               3650
# 3 Adelie  Torgersen 39.2           19.6          195               4675
# 4 Adelie  Torgersen 38.6           21.2          191               3800
# 5 Adelie  Torgersen 34.6           21.1          198               4400
# 6 Adelie  Torgersen 42.5           20.7          197               4500
#   sex  year
# 1 male 2007
# 2 male 2007
# 3 male 2007
# 4 male 2007
# 5 male 2007
# 6 male 2007

# %%
filter(penguins, body_mass_g > 3000) %>% head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen 36.7           19.3          193               3450
# 5 Adelie  Torgersen 39.3           20.6          190               3650
# 6 Adelie  Torgersen 38.9           17.8          181               3625
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 female 2007
# 5 male   2007
# 6 female 2007

# %%
penguins %>% filter(island == 'Biscoe') %>% head
# Out:
#   species island bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Biscoe 37.8           18.3          174               3400
# 2 Adelie  Biscoe 37.7           18.7          180               3600
# 3 Adelie  Biscoe 35.9           19.2          189               3800
# 4 Adelie  Biscoe 38.2           18.1          185               3950
# 5 Adelie  Biscoe 38.8           17.2          180               3800
# 6 Adelie  Biscoe 35.3           18.9          187               3800
#   sex    year
# 1 female 2007
# 2 male   2007
# 3 female 2007
# 4 male   2007
# 5 male   2007
# 6 female 2007

# %%
colnames(penguins)
# Out:
# [1] "species"           "island"            "bill_length_mm"
# [4] "bill_depth_mm"     "flipper_length_mm" "body_mass_g"
# [7] "sex"               "year"

# %% [markdown]
# #### arrange()
# * arrange() changes the order of the rows based on the value of the
# columns

# %%
penguins  %>% arrange(bill_length_mm) %>% head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Dream     32.1           15.5          188               3050
# 2 Adelie  Dream     33.1           16.1          178               2900
# 3 Adelie  Torgersen 33.5           19.0          190               3600
# 4 Adelie  Dream     34.0           17.1          185               3400
# 5 Adelie  Torgersen 34.1           18.1          193               3475
# 6 Adelie  Torgersen 34.4           18.4          184               3325
#   sex    year
# 1 female 2009
# 2 female 2008
# 3 female 2008
# 4 female 2008
# 5 NA     2007
# 6 female 2007

# %%
penguins %>% arrange(island) %>% head()
# Out:
#   species island bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Biscoe 37.8           18.3          174               3400
# 2 Adelie  Biscoe 37.7           18.7          180               3600
# 3 Adelie  Biscoe 35.9           19.2          189               3800
# 4 Adelie  Biscoe 38.2           18.1          185               3950
# 5 Adelie  Biscoe 38.8           17.2          180               3800
# 6 Adelie  Biscoe 35.3           18.9          187               3800
#   sex    year
# 1 female 2007
# 2 male   2007
# 3 female 2007
# 4 male   2007
# 5 male   2007
# 6 female 2007

# %%
arrange(penguins, flipper_length_mm) %>% head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Biscoe    37.9           18.6          172               3150
# 2 Adelie  Biscoe    37.8           18.3          174               3400
# 3 Adelie  Torgersen 40.2           17.0          176               3450
# 4 Adelie  Dream     39.5           16.7          178               3250
# 5 Adelie  Dream     37.2           18.1          178               3900
# 6 Adelie  Dream     33.1           16.1          178               2900
#   sex    year
# 1 female 2007
# 2 female 2007
# 3 female 2009
# 4 female 2007
# 5 male   2007
# 6 female 2008

# %% [markdown]
# * rearranging the rows into decending order using desc().

# %%
penguins  %>% arrange(desc(bill_length_mm)) %>% head()
# Out:
#   species   island bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Gentoo    Biscoe 59.6           17.0          230               6050
# 2 Chinstrap Dream  58.0           17.8          181               3700
# 3 Gentoo    Biscoe 55.9           17.0          228               5600
# 4 Chinstrap Dream  55.8           19.8          207               4000
# 5 Gentoo    Biscoe 55.1           16.0          230               5850
# 6 Gentoo    Biscoe 54.3           15.7          231               5650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 male   2009
# 4 male   2009
# 5 male   2009
# 6 male   2008

# %%
penguins %>% arrange(desc(body_mass_g)) %>% head()
# Out:
#   species island bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Gentoo  Biscoe 49.2           15.2          221               6300
# 2 Gentoo  Biscoe 59.6           17.0          230               6050
# 3 Gentoo  Biscoe 51.1           16.3          220               6000
# 4 Gentoo  Biscoe 48.8           16.2          222               6000
# 5 Gentoo  Biscoe 45.2           16.4          223               5950
# 6 Gentoo  Biscoe 49.8           15.9          229               5950
#   sex  year
# 1 male 2007
# 2 male 2007
# 3 male 2008
# 4 male 2009
# 5 male 2008
# 6 male 2009

# %% [markdown]
# #### distinct()

# %%
penguins %>% is.na() %>% sum()
# Out:
# [1] 19

# %%
duplicated(penguins) %>% sum()
# Out:
# [1] 0

# %%
distinct(penguins)
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Torgersen 39.1           18.7          181
# 2   Adelie    Torgersen 39.5           17.4          186
# 3   Adelie    Torgersen 40.3           18.0          195
# 4   Adelie    Torgersen   NA             NA           NA
# 5   Adelie    Torgersen 36.7           19.3          193
# 6   Adelie    Torgersen 39.3           20.6          190
# 7   Adelie    Torgersen 38.9           17.8          181
# 8   Adelie    Torgersen 39.2           19.6          195
# 9   Adelie    Torgersen 34.1           18.1          193
# 10  Adelie    Torgersen 42.0           20.2          190
# 11  Adelie    Torgersen 37.8           17.1          186
# 12  Adelie    Torgersen 37.8           17.3          180
# 13  Adelie    Torgersen 41.1           17.6          182
# 14  Adelie    Torgersen 38.6           21.2          191
# 15  Adelie    Torgersen 34.6           21.1          198
# ...

# %%
penguins  %>% distinct(species)
# Out:
#   species
# 1 Adelie
# 2 Gentoo
# 3 Chinstrap

# %%
penguins  %>% distinct(island)
# Out:
#   island
# 1 Torgersen
# 2 Biscoe
# 3 Dream

# %%
penguins %>% distinct(sex)
# Out:
#   sex
# 1 male
# 2 female
# 3 NA

# %%
penguins %>% distinct(year)
# Out:
#   year
# 1 2007
# 2 2008
# 3 2009

# %% [markdown]
# #### count()

# %%
penguins %>% count(species, sort = TRUE)
# Out:
#   species   n
# 1 Adelie    152
# 2 Gentoo    124
# 3 Chinstrap  68

# %%
penguins %>% count(sex, sort = T)
# Out:
# Warning message:
# "Factor `sex` contains implicit NA, consider using `forcats::fct_explicit_na`"
#   sex    n
# 1 male   168
# 2 female 165
# 3 NA      11

# %%
penguins %>% count(`island`, sort = T)
# Out:
#   island    n
# 1 Biscoe    168
# 2 Dream     124
# 3 Torgersen  52

# %%
penguins %>% count(year, sort =  T)
# Out:
#   year n
# 1 2009 120
# 2 2008 114
# 3 2007 110

# %%
distinct(penguins,penguins$island)
# Out:
#   penguins$island
# 1 Torgersen
# 2 Biscoe
# 3 Dream

# %% [markdown]
# ## Columns
# There are four important verbs that affect the columns without changing the
# rows:
# * mutate() creates new columns that are derived from the existing
# columns
# * select() changes which columns are present,
# * rename()
# changes the names of the columns,
# * relocate() changes the
# positions of the columns.

# %% [markdown]
# #### mutate()

# %%
penguins  %>% mutate(body_mass_KG = body_mass_g / 1000)
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Torgersen 39.1           18.7          181
# 2   Adelie    Torgersen 39.5           17.4          186
# 3   Adelie    Torgersen 40.3           18.0          195
# 4   Adelie    Torgersen   NA             NA           NA
# 5   Adelie    Torgersen 36.7           19.3          193
# 6   Adelie    Torgersen 39.3           20.6          190
# 7   Adelie    Torgersen 38.9           17.8          181
# 8   Adelie    Torgersen 39.2           19.6          195
# 9   Adelie    Torgersen 34.1           18.1          193
# 10  Adelie    Torgersen 42.0           20.2          190
# 11  Adelie    Torgersen 37.8           17.1          186
# 12  Adelie    Torgersen 37.8           17.3          180
# 13  Adelie    Torgersen 41.1           17.6          182
# 14  Adelie    Torgersen 38.6           21.2          191
# 15  Adelie    Torgersen 34.6           21.1          198
# ...

# %% [markdown]
# ### select()

# %%
penguins  %>% select(species, island, bill_length_mm)
# Out:
#     species   island    bill_length_mm
# 1   Adelie    Torgersen 39.1
# 2   Adelie    Torgersen 39.5
# 3   Adelie    Torgersen 40.3
# 4   Adelie    Torgersen   NA
# 5   Adelie    Torgersen 36.7
# 6   Adelie    Torgersen 39.3
# 7   Adelie    Torgersen 38.9
# 8   Adelie    Torgersen 39.2
# 9   Adelie    Torgersen 34.1
# 10  Adelie    Torgersen 42.0
# 11  Adelie    Torgersen 37.8
# 12  Adelie    Torgersen 37.8
# 13  Adelie    Torgersen 41.1
# 14  Adelie    Torgersen 38.6
# 15  Adelie    Torgersen 34.6
# 16  Adelie    Torgersen 36.6
# 17  Adelie    Torgersen 38.7
# 18  Adelie    Torgersen 42.5
# 19  Adelie    Torgersen 34.4
# 20  Adelie    Torgersen 46.0
# 21  Adelie    Biscoe    37.8
# 22  Adelie    Biscoe    37.7
# 23  Adelie    Biscoe    35.9
# 24  Adelie    Biscoe    38.2
# 25  Adelie    Biscoe    38.8
# 26  Adelie    Biscoe    35.3
# 27  Adelie    Biscoe    40.6
# 28  Adelie    Biscoe    40.5
# 29  Adelie    Biscoe    37.9
# 30  Adelie    Biscoe    40.5
# ...

# %%
head(penguins)
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %%
penguins  %>% select(island : flipper_length_mm) %>% head()
# Out:
#   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1 Torgersen 39.1           18.7          181
# 2 Torgersen 39.5           17.4          186
# 3 Torgersen 40.3           18.0          195
# 4 Torgersen   NA             NA           NA
# 5 Torgersen 36.7           19.3          193
# 6 Torgersen 39.3           20.6          190

# %% [markdown]
# ##### Selecting all columns except those from island  to flipper_length_mm:

# %%
penguins  %>% select(- (island :flipper_length_mm)) %>% head()
# Out:
#   species body_mass_g sex    year
# 1 Adelie  3750        male   2007
# 2 Adelie  3800        female 2007
# 3 Adelie  3250        female 2007
# 4 Adelie    NA        NA     2007
# 5 Adelie  3450        female 2007
# 6 Adelie  3650        male   2007

# %% [markdown]
# ##### Renaming the column name by using select()/

# %%
penguins  %>% select(YEAR = year)
# Out:
#     YEAR
# 1   2007
# 2   2007
# 3   2007
# 4   2007
# 5   2007
# 6   2007
# 7   2007
# 8   2007
# 9   2007
# 10  2007
# 11  2007
# 12  2007
# 13  2007
# 14  2007
# 15  2007
# 16  2007
# 17  2007
# 18  2007
# 19  2007
# 20  2007
# 21  2007
# 22  2007
# 23  2007
# 24  2007
# 25  2007
# 26  2007
# 27  2007
# 28  2007
# 29  2007
# 30  2007
# ... ...
# 315 2008
# 316 2008
# 317 2008
# 318 2008
# 319 2008
# 320 2008
# 321 2009
# 322 2009
# 323 2009
# 324 2009
# 325 2009
# 326 2009
# 327 2009
# 328 2009
# 329 2009
# 330 2009
# 331 2009
# 332 2009
# 333 2009
# 334 2009
# 335 2009
# 336 2009
# 337 2009
# 338 2009
# 339 2009
# 340 2009
# 341 2009
# 342 2009
# 343 2009
# 344 2009

# %% [markdown]
# ### rename()

# %%
penguins  %>% rename(YEAR = year) %>% head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    YEAR
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %% [markdown]
# ### Groups
# dplyr gets even more powerful when you add in the ability to work with
# groups. In this section, we’ll focus on the most important functions:
# group_by(), summarize(), and the slice family of functions.

# %% [markdown]
# ### group_by()

# %% [markdown]
# * group_by() doesn’t change the data,

# %% [markdown]
# ### summarize()

# %% [markdown]
# * calculating the average body mass of male and female sex

# %%
colnames(penguins)
# Out:
# [1] "species"           "island"            "bill_length_mm"
# [4] "bill_depth_mm"     "flipper_length_mm" "body_mass_g"
# [7] "sex"               "year"

# %%
penguins  %>% group_by(sex) %>% summarise(average_mass = mean(body_mass_g))
# Out:
# Warning message:
# "Factor `sex` contains implicit NA, consider using `forcats::fct_explicit_na`"
#   sex    average_mass
# 1 female 3862.273
# 2 male   4545.685
# 3 NA           NA

# %% [markdown]
# * This shows an warning message because there are multiple null values so now omitting them null values.

# %%
penguins <- na.omit(penguins)

# %%
penguins %>% is.na() %>% sum()
# Out:
# [1] 0

# %%
penguins %>% group_by(species) %>% summarise(avg_wght = mean(body_mass_g))
# Out:
#   species   avg_wght
# 1 Adelie    3706.164
# 2 Chinstrap 3733.088
# 3 Gentoo    5092.437

# %%
penguins %>% group_by(island) %>% summarise(Avg_Mass = mean(penguins$body_mass_g))
# Out:
#   island    Avg_Mass
# 1 Biscoe    4207.057
# 2 Dream     4207.057
# 3 Torgersen 4207.057

# %%
penguins %>% group_by(island) %>% summarise(AVG_FLP = mean(flipper_length_mm))
# Out:
#   island    AVG_FLP
# 1 Biscoe    209.5583
# 2 Dream     193.1870
# 3 Torgersen 191.5319

# %%
penguins %>% group_by(island) %>% summarise(avg_island_wght = mean(body_mass_g))
# Out:
#   island    avg_island_wght
# 1 Biscoe    4719.172
# 2 Dream     3718.902
# 3 Torgersen 3708.511

# %%
penguins %>% group_by(year) %>% summarise( Year_mass = mean(body_mass_g))
# Out:
#   year Year_mass
# 1 2007 4153.155
# 2 2008 4263.274
# 3 2009 4200.214

# %% [markdown]
# ### The slice_ Functions

# %% [markdown]
# * df |> slice_head(n = 1)
# Takes the first row from each group
# * df |> slice_tail(n = 1)
# Takes the last row in each group
# * df |> slice_min(x, n = 1)
# Takes the row with the smallest value of column x
# * df |> slice_max(x, n = 1)
# Takes the row with the largest value of column x
# * df |> slice_sample(n = 1)
# takes one random row.
