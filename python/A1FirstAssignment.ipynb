# %% [markdown]
# This is a markdown cell

# %%
#Types Of Data Analaytics

# %% [markdown]
# # There are four types of Data Analaytics

# %% [markdown]
# ## Descriptive DA

# %% [markdown]
# - What happened

# %% [markdown]
# ### Diagonostic DA

# %% [markdown]
# - Why something happened

# %% [markdown]
# #### Predictive DA

# %% [markdown]
# - Predict what is likely to happen in the future

# %% [markdown]
# ##### Presciptive DA

# %% [markdown]
# - What is the best course of action

# %% [markdown]
# <center> This line is centered

# %% [markdown]
# ![anaconda.jpeg](attachment:30091000-5e15-438c-be01-25b645838771.jpeg)
