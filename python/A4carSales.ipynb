# %%
import pandas as pd
import numpy as ny
import warnings
warnings.filterwarnings('ignore')

# %%
cardf = pd.read_csv('./Car_sales.csv')

# %%
cardf
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# ### .head() - Returnes thefirst five rows

# %%
cardf.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
cardf.head(2)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                21.5          1.8       140.0      101.2   67.3   172.4
# 1                28.4          3.2       225.0      108.1   70.3   192.9
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
#
#    Power_perf_factor
# 0          58.280150
# 1          91.370778

# %% [markdown]
# ### .tail() - Returnes the last five rows

# %%
cardf.tail()
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 152        Volvo   V40               3.545                  NaN    Passenger
# 153        Volvo   S70              15.245                  NaN    Passenger
# 154        Volvo   V70              17.531                  NaN    Passenger
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 152                24.4          1.9       160.0      100.5   67.6   176.6
# 153                27.5          2.4       168.0      104.9   69.3   185.9
# 154                28.8          2.4       168.0      104.9   69.3   186.2
# 155                45.5          2.3       236.0      104.9   71.5   185.7
# 156                36.0          2.9       201.0      109.9   72.1   189.8
#
# ...

# %%
cardf.tail(2)
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 155                45.5          2.3       236.0      104.9   71.5   185.7
# 156                36.0          2.9       201.0      109.9   72.1   189.8
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 155        3.601           18.5             23.0     4/26/2011
# 156        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 155         101.623357
# 156          85.735655

# %% [markdown]
# ### .sample() - Returnes the random rows from the tables

# %%
cardf.sample()
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 125      Porsche  Carrera Coupe                1.28               60.625
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 125    Passenger               71.02          3.4       300.0       92.6
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 125   69.5   174.5        3.032           17.0             21.0    12/21/2012
#
#      Power_perf_factor
# 125         134.390975

# %%
cardf.sample(3)
# Out:
#     Manufacturer   Model  Sales_in_thousands  __year_resale_value  \
# 139       Toyota  Celica              33.269               15.445
# 88       Mercury   Sable              67.956               11.030
# 103       Nissan  Maxima              79.853               15.125
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 139    Passenger              16.875          1.8       140.0      102.4
# 88     Passenger              19.035          3.0       153.0      108.5
# 103    Passenger              26.249          3.0       222.0      108.3
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 139   68.3   170.5        2.425           14.5             31.0    12/29/2012
# 88    73.0   199.7        3.379           16.0             24.0     9/22/2012
# 103   70.3   190.5        3.294           18.5             25.0      5/6/2011
#
#      Power_perf_factor
# 139          56.496030
# 88           62.239967
# ...

# %% [markdown]
# ### .info() - Returnes the information about the dataframe

# %%
cardf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %% [markdown]
# ### .describe() - Returnes the statistical view of the dataframe

# %%
cardf.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
cardf.describe().T
# Out:
#                      count        mean        std         min         25%  \
# Sales_in_thousands   157.0   52.998076  68.029422    0.110000   14.114000
# __year_resale_value  121.0   18.072975  11.453384    5.160000   11.260000
# Price_in_thousands   155.0   27.390755  14.351653    9.235000   18.017500
# Engine_size          156.0    3.060897   1.044653    1.000000    2.300000
# Horsepower           156.0  185.948718  56.700321   55.000000  149.500000
# Wheelbase            156.0  107.487179   7.641303   92.600000  103.000000
# Width                156.0   71.150000   3.451872   62.600000   68.400000
# Length               156.0  187.343590  13.431754  149.400000  177.575000
# Curb_weight          155.0    3.378026   0.630502    1.895000    2.971000
# Fuel_capacity        156.0   17.951923   3.887921   10.300000   15.800000
# Fuel_efficiency      154.0   23.844156   4.282706   15.000000   21.000000
# Power_perf_factor    155.0   77.043591  25.142664   23.276272   60.407707
#
# ...

# %% [markdown]
# ### .shape - Returns the dimension of the data in tuples

# %%
cardf.shape
# Out:
# (157, 16)

# %% [markdown]
# ### .size - Returns the number of cells

# %%
cardf.size
# Out:
# 2512

# %% [markdown]
# ### .columns - Returns the columns into list

# %%
cardf.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
cardf.Manufacturer
# Out:
# 0           Acura
# 1           Acura
# 3           Acura
# 4            Audi
# 5            Audi
#           ...
# 145    Volkswagen
# 146    Volkswagen
# 147    Volkswagen
# 148    Volkswagen
# 149    Volkswagen
# Name: Manufacturer, Length: 117, dtype: object

# %% [markdown]
# ### ."column name".dtype - Checks the data type of a column

# %%
cardf.Model.dtype
# Out:
# dtype('O')

# %% [markdown]
# ### .isnull().sum() - Returns the count of the null values

# %%
cardf.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %% [markdown]
# ### .isnull().mean()*100 - Returnes the null percentage

# %%
cardf.isnull().mean()*100
# Out:
# Manufacturer            0.000000
# Model                   0.000000
# Sales_in_thousands      0.000000
# __year_resale_value    22.929936
# Vehicle_type            0.000000
# Price_in_thousands      1.273885
# Engine_size             0.636943
# Horsepower              0.636943
# Wheelbase               0.636943
# Width                   0.636943
# Length                  0.636943
# Curb_weight             1.273885
# Fuel_capacity           0.636943
# Fuel_efficiency         1.910828
# Latest_Launch           0.000000
# Power_perf_factor       1.273885
# dtype: float64

# %% [markdown]
# ### .duplicated().sum() - Returnes the duplicated values

# %%
cardf.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### .dropna() - Drops the null values

# %%
cardf.dropna()
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
cardf.dropna(inplace = True)

# %%
cardf
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# ### .reset_index() - Resets the index and makes it in sequence

# %%
cardf.reset_index()
# Out:
#      index Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0        0        Acura  Integra              16.919               16.360
# 1        1        Acura       TL              39.384               19.875
# 2        3        Acura       RL               8.588               29.725
# 3        4         Audi       A4              20.397               22.255
# 4        5         Audi       A6              18.780               23.555
# ..     ...          ...      ...                 ...                  ...
# 112    145   Volkswagen     Golf               9.761               11.425
# 113    146   Volkswagen    Jetta              83.721               13.240
# 114    147   Volkswagen   Passat              51.102               16.725
# 115    148   Volkswagen   Cabrio               9.569               16.575
# 116    149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %% [markdown]
# ### .value_counts() - Returnes the number of unique value in a column

# %%
cardf.Model.value_counts()
# Out:
# Model
# Neon       2
# Integra    1
# RL         1
# TL         1
# A6         1
#           ..
# Golf       1
# Jetta      1
# Passat     1
# Cabrio     1
# GTI        1
# Name: count, Length: 116, dtype: int64

# %% [markdown]
# # Sorting

# %% [markdown]
# ### Sorting the values in ascending nd decending order according to horsepower

# %%
cardf.sort_values(by='Horsepower')
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 26     Chevrolet           Metro              21.855                5.160
# 62       Hyundai          Accent              41.184                5.860
# 130       Saturn              SC              24.546               10.590
# 129       Saturn              SL              80.620                9.200
# 57         Honda           Civic             199.685                9.850
# ..           ...             ...                 ...                  ...
# 126      Porsche  Carrera Cabrio               1.866               67.550
# 95    Mercedes-B        SL-Class               3.311               58.600
# 6           Audi              A8               1.380               39.000
# 24     Chevrolet        Corvette              17.947               36.225
# 39         Dodge           Viper               0.916               58.470
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
cardf.sort_values(by='Horsepower', ascending = False)
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 39         Dodge           Viper               0.916               58.470
# 24     Chevrolet        Corvette              17.947               36.225
# 6           Audi              A8               1.380               39.000
# 95    Mercedes-B        SL-Class               3.311               58.600
# 126      Porsche  Carrera Cabrio               1.866               67.550
# ..           ...             ...                 ...                  ...
# 57         Honda           Civic             199.685                9.850
# 130       Saturn              SC              24.546               10.590
# 129       Saturn              SL              80.620                9.200
# 62       Hyundai          Accent              41.184                5.860
# 26     Chevrolet           Metro              21.855                5.160
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %% [markdown]
# # Filtering

# %% [markdown]
# ### This data shows the vehicles with fuel efficiency less than 20

# %%
cardf[cardf['Fuel_efficiency']>20]
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# ### This data shows the vehicles made after the model named "Civic"

# %%
cardf[cardf['Model'] == 'Civic']
# Out:
#    Manufacturer  Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 57        Honda  Civic             199.685                 9.85    Passenger
#
#     Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 57              12.885          1.6       106.0      103.2   67.1   175.1
#
#     Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 57        2.339           11.9             32.0    10/21/2011
#
#     Power_perf_factor
# 57          42.879097

# %% [markdown]
# ### This data shows the vehicles that are not a passanger type

# %%
cardf[cardf['Vehicle_type'] != 'Passenger']
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 40         Dodge      Ram Pickup             227.061               15.060
# 41         Dodge       Ram Wagon              16.767               15.510
# 42         Dodge         Ram Van              31.038               13.425
# 43         Dodge          Dakota             111.313               11.260
# 45         Dodge         Caravan             181.749               12.025
# 52          Ford        Explorer             276.747               16.640
# 53          Ford        Windstar             155.787               13.175
# 54          Ford      Expedition             125.338               23.575
# 55          Ford          Ranger             220.650                7.850
# 56          Ford        F-Series             540.561               15.075
# 59         Honda            CR-V              73.203               17.710
# 60         Honda        Passport              12.855               17.525
# ...

# %% [markdown]
# ### Vehicles that has less than 2Liters of engine size

# %%
cardf[cardf['Engine_size'] < 2]
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 4           Audi       A4              20.397               22.255
# 25     Chevrolet    Prizm              32.299                9.125
# 26     Chevrolet    Metro              21.855                5.160
# 57         Honda    Civic             199.685                9.850
# 62       Hyundai   Accent              41.184                5.860
# 79    Mitsubishi   Mirage              26.232                8.325
# 101       Nissan   Sentra              42.643                8.450
# 129       Saturn       SL              80.620                9.200
# 130       Saturn       SC              24.546               10.590
# 131       Saturn       SW               5.223               10.790
# 136       Toyota  Corolla             142.535               10.025
# 139       Toyota   Celica              33.269               15.445
# ...

# %% [markdown]
# # GroupBy

# %% [markdown]
# ### Average horsepower for the particular vehicle type

# %%
cardf.groupby(['Vehicle_type'])['Horsepower'].mean().reset_index()
# Out:
#   Vehicle_type  Horsepower
# 0          Car  176.620690
# 1    Passenger  182.818182

# %% [markdown]
# ### Total price of the vehicles from the particular manufacturer

# %%
cardf.groupby(['Manufacturer'])['Price_in_thousands'].sum().reset_index()
# Out:
#    Manufacturer  Price_in_thousands
# 0         Acura              91.900
# 1          Audi             119.940
# 2           BMW              72.300
# 3         Buick             107.125
# 4      Cadillac             110.570
# 5     Chevrolet             161.315
# 6      Chrysler             111.400
# 7         Dodge             217.535
# 8          Ford             219.205
# 9         Honda             101.385
# 10      Hyundai              36.497
# 11     Infiniti              29.465
# 12         Jeep              62.975
# 13        Lexus             123.315
# 14      Lincoln              82.410
# 15   Mercedes-B             233.950
# 16      Mercury             124.490
# 17   Mitsubishi             155.172
# 18       Nissan             115.836
# 19   Oldsmobile             111.317
# 20     Plymouth              47.570
# 21      Pontiac             112.060
# 22      Porsche             187.420
# 23       Saturn              37.510
# 24       Toyota             175.478
# ...

# %% [markdown]
# # .pivot() - Creates new index and column from the existing data

# %% [markdown]
# ### Average horsepower of the vechicle type from each manufacturer

# %%
cardf.pivot_table(values='Horsepower', index='Manufacturer', columns='Vehicle_type', aggfunc="mean")
# Out:
# Vehicle_type         Car   Passenger
# Manufacturer
# Acura                NaN  191.666667
# Audi                 NaN  220.000000
# BMW                  NaN  193.000000
# Buick                NaN  206.250000
# Cadillac             NaN  250.000000
# Chevrolet            NaN  170.000000
# Chrysler             NaN  183.200000
# Dodge         170.000000  228.250000
# Ford          187.800000  165.000000
# Honda         187.000000  120.500000
# Hyundai              NaN  126.666667
# Infiniti             NaN  227.000000
# Jeep          168.333333         NaN
# Lexus                NaN  241.666667
# Lincoln              NaN  245.000000
# Mercedes-B           NaN  245.750000
# Mercury       190.000000  150.750000
# Mitsubishi    186.500000  156.600000
# Nissan        170.000000  167.666667
# Oldsmobile    187.500000  200.000000
# Plymouth      150.000000  132.000000
# Pontiac              NaN  185.000000
# Porsche              NaN  272.333333
# Saturn               NaN  108.000000
# ...

# %% [markdown]
# ### Total sales of the cars from each manufacturer according to their vehicle type

# %%
cardf.pivot_table(values='Sales_in_thousands', index='Manufacturer', columns='Vehicle_type', aggfunc='sum')
# Out:
# Vehicle_type       Car  Passenger
# Manufacturer
# Acura              NaN     64.891
# Audi               NaN     40.557
# BMW                NaN     26.758
# Buick              NaN    242.019
# Cadillac           NaN     81.450
# Chevrolet          NaN    446.370
# Chrysler           NaN    117.545
# Dodge          567.928    152.870
# Ford          1319.083    527.882
# Honda          162.087    430.587
# Hyundai            NaN    137.326
# Infiniti           NaN     23.713
# Jeep           293.153        NaN
# Lexus              NaN     43.145
# Lincoln            NaN     62.709
# Mercedes-B         NaN     66.079
# Mercury         47.989    190.010
# Mitsubishi      50.685    130.210
# Nissan          69.882    210.590
# Oldsmobile      44.378     15.802
# Plymouth        24.155     37.974
# Pontiac            NaN    330.962
# Porsche            NaN     12.128
# Saturn             NaN    110.389
# Toyota         187.439    487.647
# Volkswagen         NaN    159.749

# %% [markdown]
# # Other data filtering methods

# %%
cardf.slect_dtypes(int)

# %%
cardf.select_dtypes(float)
# Out:
#      Sales_in_thousands  __year_resale_value  Price_in_thousands  Engine_size  \
# 0                16.919               16.360               21.50          1.8
# 1                39.384               19.875               28.40          3.2
# 3                 8.588               29.725               42.00          3.5
# 4                20.397               22.255               23.99          1.8
# 5                18.780               23.555               33.95          2.8
# ..                  ...                  ...                 ...          ...
# 145               9.761               11.425               14.90          2.0
# 146              83.721               13.240               16.70          2.0
# 147              51.102               16.725               21.20          1.8
# 148               9.569               16.575               19.99          2.0
# 149               5.596               13.760               17.50          2.0
#
# ...

# %%
cardf.select_dtypes(object)
# Out:
#     Manufacturer    Model Vehicle_type Latest_Launch
# 0          Acura  Integra    Passenger      2/2/2012
# 1          Acura       TL    Passenger      6/3/2011
# 3          Acura       RL    Passenger     3/10/2011
# 4           Audi       A4    Passenger     10/8/2011
# 5           Audi       A6    Passenger      8/9/2011
# ..           ...      ...          ...           ...
# 145   Volkswagen     Golf    Passenger     1/24/2011
# 146   Volkswagen    Jetta    Passenger     8/27/2011
# 147   Volkswagen   Passat    Passenger    10/30/2012
# 148   Volkswagen   Cabrio    Passenger     5/31/2011
# 149   Volkswagen      GTI    Passenger      4/1/2011
#
# [117 rows x 4 columns]

# %% [markdown]
# # Cut method in pandas

# %%
hp = [0,150,300,500]
cartype = ['EconomyCars','SUV','SportsCars']
cardf['Speedy'] = pd.cut(cardf.Horsepower, bins=hp, labels=cartype)

# %%
cardf.sample(5)
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 76       Lincoln     Continental              13.798               20.525
# 126      Porsche  Carrera Cabrio               1.866               67.550
# 111   Oldsmobile          Aurora              14.690               19.890
# 37         Dodge         Stratus              71.186               10.185
# 129       Saturn              SL              80.620                9.200
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 76     Passenger              39.080          4.6       275.0      109.0
# 126    Passenger              74.970          3.4       300.0       92.6
# 111    Passenger              36.229          4.0       250.0      113.8
# 37     Passenger              20.230          2.5       168.0      108.0
# 129    Passenger              10.685          1.9       100.0      102.4
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
cardf.Speedy.value_counts()
# Out:
# Speedy
# SUV            70
# EconomyCars    43
# SportsCars      4
# Name: count, dtype: int64

# %%
cardf.groupby(['Speedy'])['Fuel_efficiency'].mean().reset_index()
# Out:
#         Speedy  Fuel_efficiency
# 0  EconomyCars        27.511628
# 1          SUV        22.285714
# 2   SportsCars        19.750000

# %% [markdown]
# # n_largest and n_smallest

# %% [markdown]
# ### This data illustrates the highest nd lowest sales of the vehicles

# %%
cardf.nlargest(3, 'Sales_in_thousands')
# Out:
#     Manufacturer     Model  Sales_in_thousands  __year_resale_value  \
# 56          Ford  F-Series             540.561               15.075
# 52          Ford  Explorer             276.747               16.640
# 137       Toyota     Camry             247.994               13.245
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 56           Car              26.935          4.6       220.0      138.5
# 52           Car              31.930          4.0       210.0      111.6
# 137    Passenger              17.518          2.2       133.0      105.2
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 56    79.1   224.5        4.241           25.1             18.0     8/16/2012
# 52    70.2   190.7        3.876           21.0             19.0     4/25/2012
# 137   70.1   188.5        2.998           18.5             27.0     2/10/2011
#
#      Power_perf_factor       Speedy
# 56           89.401935          SUV
# ...

# %%
cardf.nsmallest(3,'Sales_in_thousands')
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 83    Mitsubishi   3000GT               0.110                20.94
# 39         Dodge    Viper               0.916                58.47
# 108   Oldsmobile  Cutlass               1.112                11.24
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 83     Passenger              25.450          3.0       161.0       97.2
# 39     Passenger              69.725          8.0       450.0       96.2
# 108    Passenger              18.145          3.1       150.0      107.0
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 83    72.4   180.3        3.131           19.8             21.0     6/29/2012
# 39    75.7   176.7        3.375           19.0             16.0      8/7/2011
# 108   69.4   192.0        3.102           15.2             25.0     5/31/2011
#
#      Power_perf_factor       Speedy
# 83           67.544155          SUV
# ...

# %% [markdown]
# # Crosstabulation

# %% [markdown]
# ### This data shows the types of the vehicles made by the manufacturer

# %%
pd.crosstab(cardf.Manufacturer, cardf.Vehicle_type)
# Out:
# Vehicle_type  Car  Passenger
# Manufacturer
# Acura           0          3
# Audi            0          3
# BMW             0          2
# Buick           0          4
# Cadillac        0          3
# Chevrolet       0          8
# Chrysler        0          5
# Dodge           5          4
# Ford            5          5
# Honda           3          2
# Hyundai         0          3
# Infiniti        0          1
# Jeep            3          0
# Lexus           0          3
# Lincoln         0          2
# Mercedes-B      0          4
# Mercury         2          4
# Mitsubishi      2          5
# Nissan          2          3
# Oldsmobile      2          2
# Plymouth        1          2
# Pontiac         0          5
# Porsche         0          3
# Saturn          0          3
# Toyota          4          4
# Volkswagen      0          5
