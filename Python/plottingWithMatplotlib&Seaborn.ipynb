# %% [markdown]
# # <center> Plotting with Matplotlib & Seaborn

# %%
import pandas as pd 
import numpy as np 
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./Car_sales.csv')
data.head(10)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
# 5         Audi       A6              18.780               23.555    Passenger
# 6         Audi       A8               1.380               39.000    Passenger
# 7          BMW     323i              19.747                  NaN    Passenger
# 8          BMW     328i               9.231               28.675    Passenger
# 9          BMW     528i              17.527               36.125    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
# 6               62.00          4.2       310.0      113.0   74.0   198.2
# 7               26.99          2.5       170.0      107.3   68.4   176.0
# 8               33.40          2.8       193.0      107.3   68.5   176.0
# 9               38.90          2.8       193.0      111.4   70.9   188.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
# 2        3.470           17.2             26.0      1/4/2012
# 3        3.850           18.0             22.0     3/10/2011
# 4        2.998           16.4             27.0     10/8/2011
# 5        3.561           18.5             22.0      8/9/2011
# 6        3.902           23.7             21.0     2/27/2012
# 7        3.179           16.6             26.0     6/28/2011
# 8        3.197           16.6             24.0     1/29/2012
# 9        3.472           18.5             25.0      4/4/2011
#
#    Power_perf_factor
# 0          58.280150
# 1          91.370778
# 2                NaN
# 3          91.389779
# 4          62.777639
# 5          84.565105
# 6         134.656858
# 7          71.191207
# 8          81.877069
# 9          83.998724

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
#  15  Power_perf_factor    155 non-null    float64
# dtypes: float64(12), object(4)
# memory usage: 19.8+ KB

# %%
data.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# 25%       2.300000  149.500000  103.000000   68.400000  177.575000
# 50%       3.000000  177.500000  107.000000   70.550000  187.900000
# 75%       3.575000  215.000000  112.200000   73.425000  196.125000
# max       8.000000  450.000000  138.700000   79.900000  224.500000
#
#        Curb_weight  Fuel_capacity  Fuel_efficiency  Power_perf_factor
# count   155.000000     156.000000       154.000000         155.000000
# mean      3.378026      17.951923        23.844156          77.043591
# std       0.630502       3.887921         4.282706          25.142664
# min       1.895000      10.300000        15.000000          23.276272
# 25%       2.971000      15.800000        21.000000          60.407707
# 50%       3.342000      17.200000        24.000000          72.030917
# 75%       3.799500      19.575000        26.000000          89.414878
# max       5.572000      32.000000        45.000000         188.144323

# %%
data.isnull().mean()*100
# Out:
# Manufacturer            0.000000
# Model                   0.000000
# Sales_in_thousands      0.000000
# __year_resale_value    22.929936
# Vehicle_type            0.000000
# Price_in_thousands      1.273885
# Engine_size             0.636943
# Horsepower              0.636943
# Wheelbase               0.636943
# Width                   0.636943
# Length                  0.636943
# Curb_weight             1.273885
# Fuel_capacity           0.636943
# Fuel_efficiency         1.910828
# Latest_Launch           0.000000
# Power_perf_factor       1.273885
# dtype: float64

# %%
data.dropna(inplace=True)
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (117, 16)

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Histogram

# %%
sns.histplot(data = data, x = 'Sales_in_thousands')
plt.show()

# %%
sns.histplot(data = data, x = 'Engine_size')
plt.show()

# %%
sns.histplot(data = data, x = 'Wheelbase')
plt.show()

# %%
sns.histplot(data = data, x= 'Width')
plt.show()

# %% [markdown]
# ## Box plot

# %%
sns.boxplot(data = data, 
           x = 'Engine_size')
plt.show()

# %%
sns.boxplot(data = data, 
           y = 'Engine_size')
plt.show()

# %%
sns.boxplot(data = data,
           y = 'Horsepower')
plt.show()

# %%
sns.boxplot(data=data, y='Sales_in_thousands')
plt.show()

# %%
sns.boxplot(data= data.Horsepower)
plt.show()

# %% [markdown]
# ## Kernel Density Estimation Plot (KDE PLOT)

# %%
sns.kdeplot(data = data, x = 'Sales_in_thousands')
plt.show()

# %%
sns.boxenplot(data = data, y = 'Sales_in_thousands')
plt.show()

# %%
sns.boxenplot(data = data,
             y = 'Horsepower')
plt.show()

# %%
sns.violinplot(data = data, y = 'Sales_in_thousands')
plt.show()

# %% [markdown]
# ### Sub plots

# %%
sns.histplot(data=data)
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.boxplot(data=data)
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.xticks(rotation = 90)
sns.boxplot(data=data)
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.xticks(rotation = 45)
sns.boxplot(data=data)
plt.show()

# %%
sns.kdeplot(data=data)
plt.show()

# %% [markdown]
# ### For loop to plot subplots

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
for i in data.columns:
    print(i)
# Out:
# Manufacturer
# Model
# Sales_in_thousands
# __year_resale_value
# Vehicle_type
# Price_in_thousands
# Engine_size
# Horsepower
# Wheelbase
# Width
# Length
# Curb_weight
# Fuel_capacity
# Fuel_efficiency
# Latest_Launch
# Power_perf_factor

# %%
for i in data.columns:
    if data[i].dtypes != 'object':
        sns.boxplot(y=data[i])
        plt.show()

# %%
for i in data.columns:
    if data[i].dtypes != 'object':
        sns.histplot(x=data[i])
        plt.show()

# %%
for i in data.columns:
    if data[i].dtypes != 'object':
        sns.kdeplot(data=data[i])
        plt.show()

# %% [markdown]
# ### Subplots in matplotlib

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(data=data,y='Sales_in_thousands')

plt.subplot(2,2,2)
sns.boxplot(data=data,y='Price_in_thousands')

plt.subplot(2,2,3)
sns.boxplot(data=data,y='Engine_size')

plt.subplot(2,2,4)
sns.boxplot(data=data,y='Horsepower')

plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.boxplot(data=data,y='Sales_in_thousands')

plt.subplot(1,2,2)
sns.boxplot(data=data,y='Price_in_thousands')

plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(data=data,y='Sales_in_thousands')

plt.subplot(2,2,2)
sns.boxplot(data=data,y='Price_in_thousands')

plt.subplot(2,2,3)
sns.boxplot(data=data,y='Engine_size')

plt.show()

# %% [markdown]
# ## Line charts

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=data, x='__year_resale_value', y ='Price_in_thousands')
plt.xlabel('Year Resale Value')
plt.ylabel('Price')
plt.title('LINE CHART')
plt.show()

# %% [markdown]
# ### Count plot

# %%
plt.figure(figsize=(16,5))
sns.countplot(data=data,x='Manufacturer')
plt.xticks(rotation = 90)
plt.show()

# %%
sns.countplot(data = data, x = 'Vehicle_type')
plt.show()

# %% [markdown]
# ## Area chart

# %%
plt.figure(figsize=(18,5))
plt.stackplot(data.Manufacturer,data.Sales_in_thousands)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(18,5))
plt.stackplot(data.Manufacturer,data.Sales_in_thousands, data.Price_in_thousands)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(18,5))
plt.stackplot(data.Manufacturer,data.Sales_in_thousands, data.Price_in_thousands, data.Horsepower)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Horizontal bar chart

# %%
plt.figure(figsize=(6,12))
sns.barplot(data=data, x='Sales_in_thousands', y='Manufacturer')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Vertical Bar plot

# %%
plt.figure(figsize=(12,4))
sns.barplot(data=data, x='Manufacturer', y='Horsepower')
plt.xticks(rotation = 90)
plt.show()

# %%
sns.barplot(data = data, x = 'Vehicle_type', y = 'Horsepower')
plt.show()

# %%
sns.barplot(data = data, x = 'Vehicle_type', y = 'Sales_in_thousands')
plt.show()

# %% [markdown]
# ## Scatter plot

# %%
sns.scatterplot(data=data, x='Horsepower', y='Sales_in_thousands')
plt.show()

# %%
sns.scatterplot(data = data, x = 'Engine_size', y = 'Horsepower')
plt.show()

# %%
sns.scatterplot(data = data, x = 'Horsepower', y = 'Fuel_efficiency')
plt.show()

# %%
sns.scatterplot(data = data, x = 'Engine_size', y = 'Horsepower', hue='Vehicle_type')
plt.show()

# %%
sns.scatterplot(data = data, x = 'Engine_size', y = 'Horsepower', hue='Manufacturer')
plt.show()

# %%
sns.scatterplot(data=data, x='Horsepower', y='Sales_in_thousands', hue='Vehicle_type')
plt.show()

# %%
sns.scatterplot(data=data, x='Horsepower', y='Sales_in_thousands',size= '__year_resale_value')
plt.show()

# %% [markdown]
# ### Pie chart

# %%
data.Vehicle_type.value_counts()
# Out:
# Vehicle_type
# Passenger    88
# Car          29
# Name: count, dtype: int64

# %%
data.Vehicle_type.value_counts().index
# Out:
# Index(['Passenger', 'Car'], dtype='object', name='Vehicle_type')

# %%
palette_color = sns.color_palette('dark')

# %%
plt.pie(data=data, x=data.Vehicle_type.value_counts());
plt.show()

# %%
plt.pie(data=data, x=data.Vehicle_type.value_counts(),explode = [0.1, 0],labels=['Passenger', 'Car'],autopct='%0.2f%%')
plt.show()

# %% [markdown]
# ## Correlation matrix or Heatmap

# %%
data_numerical = data.select_dtypes(float)
data_numerical
# Out:
#      Sales_in_thousands  __year_resale_value  Price_in_thousands  Engine_size  \
# 0                16.919               16.360               21.50          1.8
# 1                39.384               19.875               28.40          3.2
# 3                 8.588               29.725               42.00          3.5
# 4                20.397               22.255               23.99          1.8
# 5                18.780               23.555               33.95          2.8
# ..                  ...                  ...                 ...          ...
# 145               9.761               11.425               14.90          2.0
# 146              83.721               13.240               16.70          2.0
# 147              51.102               16.725               21.20          1.8
# 148               9.569               16.575               19.99          2.0
# 149               5.596               13.760               17.50          2.0
#
#      Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# 0         140.0      101.2   67.3   172.4        2.639           13.2
# 1         225.0      108.1   70.3   192.9        3.517           17.2
# 3         210.0      114.6   71.4   196.6        3.850           18.0
# 4         150.0      102.6   68.2   178.0        2.998           16.4
# 5         200.0      108.7   76.1   192.0        3.561           18.5
# ..          ...        ...    ...     ...          ...            ...
# 145       115.0       98.9   68.3   163.3        2.767           14.5
# 146       115.0       98.9   68.3   172.3        2.853           14.5
# 147       150.0      106.4   68.5   184.1        3.043           16.4
# 148       115.0       97.4   66.7   160.4        3.079           13.7
# 149       115.0       98.9   68.3   163.3        2.762           14.6
#
#      Fuel_efficiency  Power_perf_factor
# 0               28.0          58.280150
# 1               25.0          91.370778
# 3               22.0          91.389779
# 4               27.0          62.777639
# 5               22.0          84.565105
# ..               ...                ...
# 145             26.0          46.943877
# 146             26.0          47.638237
# 147             27.0          61.701381
# 148             26.0          48.907372
# 149             26.0          47.946841
#
# [117 rows x 12 columns]

# %%
data_numerical.corr()
# Out:
#                      Sales_in_thousands  __year_resale_value  \
# Sales_in_thousands             1.000000            -0.275426
# __year_resale_value           -0.275426             1.000000
# Price_in_thousands            -0.251705             0.954757
# Engine_size                    0.038111             0.527187
# Horsepower                    -0.152538             0.773110
# Wheelbase                      0.406839            -0.053685
# Width                          0.177802             0.178128
# Length                         0.272336             0.025390
# Curb_weight                    0.067184             0.363274
# Fuel_capacity                  0.138045             0.324796
# Fuel_efficiency               -0.066927            -0.398459
# Power_perf_factor             -0.175562             0.829511
#
#                      Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# Sales_in_thousands            -0.251705     0.038111   -0.152538   0.406839
# __year_resale_value            0.954757     0.527187    0.773110  -0.053685
# Price_in_thousands             1.000000     0.649170    0.853455   0.067042
# Engine_size                    0.649170     1.000000    0.861618   0.410020
# Horsepower                     0.853455     0.861618    1.000000   0.225905
# Wheelbase                      0.067042     0.410020    0.225905   1.000000
# Width                          0.301292     0.671756    0.507275   0.675559
# Length                         0.182592     0.537343    0.400968   0.853669
# Curb_weight                    0.511400     0.742831    0.598603   0.675609
# Fuel_capacity                  0.406496     0.616862    0.479790   0.658654
# Fuel_efficiency               -0.479539    -0.724871   -0.595844  -0.470455
# Power_perf_factor              0.905002     0.841005    0.994071   0.200228
#
#                         Width    Length  Curb_weight  Fuel_capacity  \
# Sales_in_thousands   0.177802  0.272336     0.067184       0.138045
# __year_resale_value  0.178128  0.025390     0.363274       0.324796
# Price_in_thousands   0.301292  0.182592     0.511400       0.406496
# Engine_size          0.671756  0.537343     0.742831       0.616862
# Horsepower           0.507275  0.400968     0.598603       0.479790
# Wheelbase            0.675559  0.853669     0.675609       0.658654
# Width                1.000000  0.743226     0.735957       0.672191
# Length               0.743226  1.000000     0.684305       0.562504
# Curb_weight          0.735957  0.684305     1.000000       0.847994
# Fuel_capacity        0.672191  0.562504     0.847994       1.000000
# Fuel_efficiency     -0.599604 -0.465682    -0.818819      -0.808506
# Power_perf_factor    0.478889  0.366831     0.597586       0.478484
#
#                      Fuel_efficiency  Power_perf_factor
# Sales_in_thousands         -0.066927          -0.175562
# __year_resale_value        -0.398459           0.829511
# Price_in_thousands         -0.479539           0.905002
# Engine_size                -0.724871           0.841005
# Horsepower                 -0.595844           0.994071
# Wheelbase                  -0.470455           0.200228
# Width                      -0.599604           0.478889
# Length                     -0.465682           0.366831
# Curb_weight                -0.818819           0.597586
# Fuel_capacity              -0.808506           0.478484
# Fuel_efficiency             1.000000          -0.588427
# Power_perf_factor          -0.588427           1.000000

# %%
sns.heatmap(data_numerical.corr())
plt.show()

# %%
sns.heatmap(data_numerical.corr(),annot=True)
plt.show()

# %% [markdown]
# #### More cooler approach

# %%
data_numerical.corr()[['Price_in_thousands']]
# Out:
#                      Price_in_thousands
# Sales_in_thousands            -0.251705
# __year_resale_value            0.954757
# Price_in_thousands             1.000000
# Engine_size                    0.649170
# Horsepower                     0.853455
# Wheelbase                      0.067042
# Width                          0.301292
# Length                         0.182592
# Curb_weight                    0.511400
# Fuel_capacity                  0.406496
# Fuel_efficiency               -0.479539
# Power_perf_factor              0.905002

# %%
sns.heatmap(data_numerical.corr()[["Price_in_thousands"]].sort_values(by="Price_in_thousands", ascending=False), vmin=-1, vmax=1,annot=True, 
            cmap="Greens")
plt.plot();

# %%
sns.heatmap(data_numerical.corr()[["Horsepower"]].sort_values(by="Horsepower", ascending=False), vmin=-1, vmax=1,annot=True, cmap="Reds")
plt.plot();

# %% [markdown]
# ### Regplot

# %%
sns.regplot(data = data, x = 'Horsepower', y= 'Sales_in_thousands')
plt.show()

# %%
sns.regplot(data = data, x = 'Horsepower', y= 'Price_in_thousands')
plt.show()

# %% [markdown]
# ### Relplot

# %%
sns.relplot(data = data, x = 'Horsepower', y= 'Sales_in_thousands', size='Price_in_thousands')
plt.show()

# %% [markdown]
# ## Catplot

# %%
sns.catplot(data = data, x = 'Vehicle_type', y= 'Sales_in_thousands')
plt.show()

# %% [markdown]
# ## Boxen plot

# %%
sns.boxenplot(data=data, y='Horsepower')
plt.show()

# %% [markdown]
# ## violin plot

# %%
sns.violinplot(data=data, y='Horsepower')
plt.show()

# %% [markdown]
# ### Joint plot

# %%
sns.jointplot(data = data, x = 'Horsepower', y= 'Sales_in_thousands')
plt.show()

# %%
sns.jointplot(data = data, x = 'Horsepower', y= 'Sales_in_thousands', kind='hex')
plt.show()

# %% [markdown]
# ## Swarm plot

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
sns.swarmplot(data = data, x = 'Vehicle_type', y= 'Sales_in_thousands')
plt.show()

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(data=data)
plt.show()

# %% [markdown]
# ### Loading the Seaborn datasets

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('penguins')
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
data_tips = sns.load_dataset('tips')

# %%
data_tips.sample(30)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 90        28.97  3.00    Male    Yes   Fri  Dinner     2
# 70        12.02  1.97    Male     No   Sat  Dinner     2
# 162       16.21  2.00  Female     No   Sun  Dinner     3
# 200       18.71  4.00    Male    Yes  Thur   Lunch     3
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2
# 104       20.92  4.08  Female     No   Sat  Dinner     2
# 114       25.71  4.00  Female     No   Sun  Dinner     3
# 119       24.08  2.92  Female     No  Thur   Lunch     4
# 138       16.00  2.00    Male    Yes  Thur   Lunch     2
# 64        17.59  2.64    Male     No   Sat  Dinner     3
# 123       15.95  2.00    Male     No  Thur   Lunch     2
# 65        20.08  3.15    Male     No   Sat  Dinner     3
# 175       32.90  3.11    Male    Yes   Sun  Dinner     2
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 167       31.71  4.50    Male     No   Sun  Dinner     4
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2
# 48        28.55  2.05    Male     No   Sun  Dinner     3
# 98        21.01  3.00    Male    Yes   Fri  Dinner     2
# 61        13.81  2.00    Male    Yes   Sat  Dinner     2
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 150       14.07  2.50    Male     No   Sun  Dinner     2
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 17        16.29  3.71    Male     No   Sun  Dinner     3
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 129       22.82  2.18    Male     No  Thur   Lunch     3
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 33        20.69  2.45  Female     No   Sat  Dinner     4

# %%
sns.countplot(data = data_tips, x = 'sex')
plt.show()

# %%
sns.countplot(data = data_tips, x = 'sex', hue='smoker')
plt.show()

# %%
sns.barplot(data=data_tips, 
           x = 'sex',
           y = 'total_bill')
plt.show()

# %%
sns.pairplot(data = data_tips)
plt.show()
